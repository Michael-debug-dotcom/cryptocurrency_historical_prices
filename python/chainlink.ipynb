# %%
import pandas as pd

# %%
df = pd.read_csv(r'coin_ChainLink.csv')

# %%
df.head()
# Out:
#    SNo       Name Symbol                 Date      High       Low      Open  \
# 0    1  Chainlink   LINK  2017-09-21 23:59:59  0.207892  0.155292  0.189132
# 1    2  Chainlink   LINK  2017-09-22 23:59:59  0.181675  0.139869  0.169826
# 2    3  Chainlink   LINK  2017-09-23 23:59:59  0.157440  0.126297  0.149562
# 3    4  Chainlink   LINK  2017-09-24 23:59:59  0.190250  0.130275  0.131110
# 4    5  Chainlink   LINK  2017-09-25 23:59:59  0.182637  0.158580  0.170636
#
#       Close     Volume   Marketcap
# 0  0.169680  2126270.0  59388000.0
# 1  0.150503  1423220.0  52676050.0
# 2  0.131129  1186670.0  45895150.0
# 3  0.170278  1025740.0  59597300.0
# 4  0.182198  1021370.0  63769300.0

# %%
# format the specified columns

columns_to_format = ['High', 'Low', 'Open', 'Close', 'Volume', 'Marketcap']
df[columns_to_format] = df[columns_to_format].applymap(lambda x: f'{x:.2f}'.replace('.', ','))

# format date column to date

df['Date'] = pd.to_datetime(df['Date'])

df
# Out:
#        SNo       Name Symbol                Date   High    Low   Open  Close  \
# 0        1  Chainlink   LINK 2017-09-21 23:59:59   0,21   0,16   0,19   0,17
# 1        2  Chainlink   LINK 2017-09-22 23:59:59   0,18   0,14   0,17   0,15
# 2        3  Chainlink   LINK 2017-09-23 23:59:59   0,16   0,13   0,15   0,13
# 3        4  Chainlink   LINK 2017-09-24 23:59:59   0,19   0,13   0,13   0,17
# 4        5  Chainlink   LINK 2017-09-25 23:59:59   0,18   0,16   0,17   0,18
# ...    ...        ...    ...                 ...    ...    ...    ...    ...
# 1380  1381  Chainlink   LINK 2021-07-02 23:59:59  18,52  17,31  18,22  18,28
# 1381  1382  Chainlink   LINK 2021-07-03 23:59:59  18,89  17,90  18,29  18,54
# 1382  1383  Chainlink   LINK 2021-07-04 23:59:59  19,89  18,03  18,55  19,26
# 1383  1384  Chainlink   LINK 2021-07-05 23:59:59  19,25  17,81  19,25  18,37
# 1384  1385  Chainlink   LINK 2021-07-06 23:59:59  20,24  18,35  18,35  20,08
#
#              Volume      Marketcap
# ...

# %%
# save df to csv

df.to_csv(r'chainlink.csv', index=False)
