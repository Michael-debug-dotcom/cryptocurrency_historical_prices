# %%
import pandas as pd

# %%
df = pd.read_csv(r'coin_BinanceCoin.csv')

# %%
df.head()
# Out:
#    SNo          Name Symbol                 Date      High       Low  \
# 0    1  Binance Coin    BNB  2017-07-26 23:59:59  0.109013  0.099266
# 1    2  Binance Coin    BNB  2017-07-27 23:59:59  0.108479  0.100888
# 2    3  Binance Coin    BNB  2017-07-28 23:59:59  0.109019  0.101473
# 3    4  Binance Coin    BNB  2017-07-29 23:59:59  0.111264  0.101108
# 4    5  Binance Coin    BNB  2017-07-30 23:59:59  0.108138  0.103162
#
#        Open     Close    Volume   Marketcap
# 0  0.105893  0.105138  200395.0  10513800.0
# 1  0.105108  0.107737  344499.0  10773700.0
# 2  0.107632  0.104067  342568.0  10406700.0
# 3  0.104782  0.107811  340218.0  10781100.0
# 4  0.107935  0.106414  224261.0  10641400.0

# %%
# format the specified columns

columns_to_format = ['High', 'Low', 'Open', 'Close', 'Volume', 'Marketcap']
df[columns_to_format] = df[columns_to_format].applymap(lambda x: f'{x:.2f}'.replace('.', ','))

# format date column to date

df['Date'] = pd.to_datetime(df['Date'])

df
# Out:
#        SNo          Name Symbol                Date    High     Low    Open  \
# 0        1  Binance Coin    BNB 2017-07-26 23:59:59    0,11    0,10    0,11
# 1        2  Binance Coin    BNB 2017-07-27 23:59:59    0,11    0,10    0,11
# 2        3  Binance Coin    BNB 2017-07-28 23:59:59    0,11    0,10    0,11
# 3        4  Binance Coin    BNB 2017-07-29 23:59:59    0,11    0,10    0,10
# 4        5  Binance Coin    BNB 2017-07-30 23:59:59    0,11    0,10    0,11
# ...    ...           ...    ...                 ...     ...     ...     ...
# 1437  1438  Binance Coin    BNB 2021-07-02 23:59:59  290,62  277,35  287,75
# 1438  1439  Binance Coin    BNB 2021-07-03 23:59:59  302,61  283,43  287,22
# 1439  1440  Binance Coin    BNB 2021-07-04 23:59:59  314,71  292,79  298,11
# 1440  1441  Binance Coin    BNB 2021-07-05 23:59:59  307,68  293,52  307,68
# 1441  1442  Binance Coin    BNB 2021-07-06 23:59:59  321,52  302,20  302,20
#
#        Close         Volume       Marketcap
# ...

# %%
# save df to csv

df.to_csv(r'binance.csv', index=False)
