# %%
import pandas as pd

# %%
df = pd.read_csv(r'C:\Users\MDELANEY1\OneDrive - Anglo American\Documents\Personal\Data projects\cryptocurrency historical prices\raw data\coin_NEM.csv')

# %%
df.head()
# Out:
#    SNo Name Symbol                 Date      High       Low      Open  \
# 0    1  NEM    XEM  2015-04-02 23:59:59  0.000323  0.000227  0.000242
# 1    2  NEM    XEM  2015-04-03 23:59:59  0.000330  0.000291  0.000309
# 2    3  NEM    XEM  2015-04-04 23:59:59  0.000318  0.000251  0.000310
# 3    4  NEM    XEM  2015-04-05 23:59:59  0.000283  0.000218  0.000272
# 4    5  NEM    XEM  2015-04-06 23:59:59  0.000299  0.000229  0.000232
#
#       Close        Volume     Marketcap
# 0  0.000314  28549.400391  2.823534e+06
# 1  0.000310  20677.900391  2.792457e+06
# 2  0.000277  23550.199219  2.488770e+06
# 3  0.000232  26800.199219  2.087388e+06
# 4  0.000289  22511.500000  2.598354e+06

# %%
# format the specified columns

columns_to_format = ['High', 'Low', 'Open', 'Close', 'Volume', 'Marketcap']
df[columns_to_format] = df[columns_to_format].applymap(lambda x: f'{x:.2f}'.replace('.', ','))

# format date column to date

df['Date'] = pd.to_datetime(df['Date'])

df
# Out:
#        SNo Name Symbol                Date  High   Low  Open Close  \
# 0        1  NEM    XEM 2015-04-02 23:59:59  0,00  0,00  0,00  0,00
# 1        2  NEM    XEM 2015-04-03 23:59:59  0,00  0,00  0,00  0,00
# 2        3  NEM    XEM 2015-04-04 23:59:59  0,00  0,00  0,00  0,00
# 3        4  NEM    XEM 2015-04-05 23:59:59  0,00  0,00  0,00  0,00
# 4        5  NEM    XEM 2015-04-06 23:59:59  0,00  0,00  0,00  0,00
# ...    ...  ...    ...                 ...   ...   ...   ...   ...
# 2283  2284  NEM    XEM 2021-07-02 23:59:59  0,13  0,12  0,13  0,13
# 2284  2285  NEM    XEM 2021-07-03 23:59:59  0,14  0,13  0,13  0,13
# 2285  2286  NEM    XEM 2021-07-04 23:59:59  0,14  0,13  0,13  0,14
# 2286  2287  NEM    XEM 2021-07-05 23:59:59  0,14  0,13  0,14  0,13
# 2287  2288  NEM    XEM 2021-07-06 23:59:59  0,14  0,13  0,13  0,13
#
#            Volume      Marketcap
# 0        28549,40     2823534,00
# 1        20677,90     2792457,00
# 2        23550,20     2488770,00
# ...

# %%
# save df to csv

df.to_csv(r'C:\Users\MDELANEY1\OneDrive - Anglo American\Documents\Personal\Data projects\cryptocurrency historical prices\cleaned data\nem.csv', index=False)
