# %%
import pandas as pd

# %%
df = pd.read_csv(r'C:\Users\MDELANEY1\OneDrive - Anglo American\Documents\Personal\Data projects\cryptocurrency historical prices\raw data\coin_Tether.csv')

# %%
df.head()
# Out:
#    SNo    Name Symbol                 Date      High       Low      Open  \
# 0    1  Tether   USDT  2015-02-26 23:59:59  1.212320  1.194710  1.210420
# 1    2  Tether   USDT  2015-03-02 23:59:59  0.607890  0.568314  0.571249
# 2    3  Tether   USDT  2015-03-03 23:59:59  0.606229  0.604416  0.605129
# 3    4  Tether   USDT  2015-03-06 23:59:59  1.000000  1.000000  1.000000
# 4    5  Tether   USDT  2015-03-07 23:59:59  1.000000  1.000000  1.000000
#
#       Close        Volume    Marketcap
# 0  1.205740      5.955460  303364.1840
# 1  0.606502      3.032500  152595.9032
# 2  0.606229      3.031130  152527.2164
# 3  1.000000     92.647202  251600.0000
# 4  1.000000  58196.800781  251600.0000

# %%
# format the specified columns

columns_to_format = ['High', 'Low', 'Open', 'Close', 'Volume', 'Marketcap']
df[columns_to_format] = df[columns_to_format].applymap(lambda x: f'{x:.2f}'.replace('.', ','))

# format date column to date

df['Date'] = pd.to_datetime(df['Date'])

df
# Out:
#        SNo    Name Symbol                Date  High   Low  Open Close  \
# 0        1  Tether   USDT 2015-02-26 23:59:59  1,21  1,19  1,21  1,21
# 1        2  Tether   USDT 2015-03-02 23:59:59  0,61  0,57  0,57  0,61
# 2        3  Tether   USDT 2015-03-03 23:59:59  0,61  0,60  0,61  0,61
# 3        4  Tether   USDT 2015-03-06 23:59:59  1,00  1,00  1,00  1,00
# 4        5  Tether   USDT 2015-03-07 23:59:59  1,00  1,00  1,00  1,00
# ...    ...     ...    ...                 ...   ...   ...   ...   ...
# 2313  2314  Tether   USDT 2021-07-02 23:59:59  1,00  1,00  1,00  1,00
# 2314  2315  Tether   USDT 2021-07-03 23:59:59  1,00  1,00  1,00  1,00
# 2315  2316  Tether   USDT 2021-07-04 23:59:59  1,00  1,00  1,00  1,00
# 2316  2317  Tether   USDT 2021-07-05 23:59:59  1,00  1,00  1,00  1,00
# 2317  2318  Tether   USDT 2021-07-06 23:59:59  1,00  1,00  1,00  1,00
#
#               Volume       Marketcap
# 0               5,96       303364,18
# 1               3,03       152595,90
# ...

# %%
# save df to csv

df.to_csv(r'C:\Users\MDELANEY1\OneDrive - Anglo American\Documents\Personal\Data projects\cryptocurrency historical prices\cleaned data\tether.csv', index=False)
